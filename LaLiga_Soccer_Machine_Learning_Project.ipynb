# %% [markdown]
# <a href="https://colab.research.google.com/github/embustos/LaLiga-ML-Project/blob/main/LaLiga_Soccer_Machine_Learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/12/2023-2024/2023-2024-La-Liga-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup #parses HTML

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0] #css selector, selects any table elements that have the name stats_table

# %%
links = standings_table.find_all('a') #using find_all instead of select since 'select' is a css selector, find_all only can find tags in HTML

# %%
links = [l.get('href') for l in links] #iterates through all the a tags and finds the value of the href property

# %%
links = [l for l in links if '/squads/' in l] #this will only find the links in the href property that have the 'squads' links so we can isolate the teams in the standings table

# %%
links
# Out:
# ['/en/squads/53a2f082/2023-2024/Real-Madrid-Stats',
#  '/en/squads/206d90db/2023-2024/Barcelona-Stats',
#  '/en/squads/9024a00a/2023-2024/Girona-Stats',
#  '/en/squads/db3b9613/2023-2024/Atletico-Madrid-Stats',
#  '/en/squads/2b390eca/2023-2024/Athletic-Club-Stats',
#  '/en/squads/e31d1cd9/2023-2024/Real-Sociedad-Stats',
#  '/en/squads/fc536746/2023-2024/Real-Betis-Stats',
#  '/en/squads/2a8183b3/2023-2024/Villarreal-Stats',
#  '/en/squads/dcc91a7b/2023-2024/Valencia-Stats',
#  '/en/squads/8d6fd021/2023-2024/Alaves-Stats',
#  '/en/squads/03c57e2b/2023-2024/Osasuna-Stats',
#  '/en/squads/7848bd64/2023-2024/Getafe-Stats',
#  '/en/squads/f25da7fb/2023-2024/Celta-Vigo-Stats',
#  '/en/squads/ad2be733/2023-2024/Sevilla-Stats',
#  '/en/squads/2aa12281/2023-2024/Mallorca-Stats',
#  '/en/squads/0049d422/2023-2024/Las-Palmas-Stats',
#  '/en/squads/98e8af82/2023-2024/Rayo-Vallecano-Stats',
#  '/en/squads/ee7c297c/2023-2024/Cadiz-Stats',
#  '/en/squads/78ecf4bb/2023-2024/Almeria-Stats',
#  '/en/squads/a0435291/2023-2024/Granada-Stats']

# %%
team_urls = [f'https://fbref.com{l}' for l in links] #used f string formatting so we can turn the links above into absolute links

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/53a2f082/2023-2024/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/206d90db/2023-2024/Barcelona-Stats',
#  'https://fbref.com/en/squads/9024a00a/2023-2024/Girona-Stats',
#  'https://fbref.com/en/squads/db3b9613/2023-2024/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/2b390eca/2023-2024/Athletic-Club-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/2023-2024/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/fc536746/2023-2024/Real-Betis-Stats',
#  'https://fbref.com/en/squads/2a8183b3/2023-2024/Villarreal-Stats',
#  'https://fbref.com/en/squads/dcc91a7b/2023-2024/Valencia-Stats',
#  'https://fbref.com/en/squads/8d6fd021/2023-2024/Alaves-Stats',
#  'https://fbref.com/en/squads/03c57e2b/2023-2024/Osasuna-Stats',
#  'https://fbref.com/en/squads/7848bd64/2023-2024/Getafe-Stats',
#  'https://fbref.com/en/squads/f25da7fb/2023-2024/Celta-Vigo-Stats',
#  'https://fbref.com/en/squads/ad2be733/2023-2024/Sevilla-Stats',
#  'https://fbref.com/en/squads/2aa12281/2023-2024/Mallorca-Stats',
#  'https://fbref.com/en/squads/0049d422/2023-2024/Las-Palmas-Stats',
#  'https://fbref.com/en/squads/98e8af82/2023-2024/Rayo-Vallecano-Stats',
#  'https://fbref.com/en/squads/ee7c297c/2023-2024/Cadiz-Stats',
#  'https://fbref.com/en/squads/78ecf4bb/2023-2024/Almeria-Stats',
#  'https://fbref.com/en/squads/a0435291/2023-2024/Granada-Stats']

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd #pandas, python data analysis library

matches = pd.read_html(data.text, match = "Scores & Fixtures") #scans all the table tags and we only want the Scores & Fixtures table
# Out:
# <ipython-input-15-61c597cbf58c>:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match = "Scores & Fixtures") #scans all the table tags and we only want the Scores & Fixtures table

# %%
soup = BeautifulSoup(data.text)

# %% [markdown]
# Obtaning the Shooting Data

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links] #again find the urls with the href tags

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]
#filters the urls and search only for the shooting stats,
#since some links dont have href we have to use if
#conditional statement to find the correct link

# %%
links
# Out:
# ['/en/squads/53a2f082/2023-2024/matchlogs/all_comps/shooting/Real-Madrid-Match-Logs-All-Competitions',
#  '/en/squads/53a2f082/2023-2024/matchlogs/all_comps/shooting/Real-Madrid-Match-Logs-All-Competitions',
#  '/en/squads/53a2f082/2023-2024/matchlogs/all_comps/shooting/Real-Madrid-Match-Logs-All-Competitions',
#  '/en/squads/53a2f082/2023-2024/matchlogs/all_comps/shooting/Real-Madrid-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match = "Shooting")[0]
# Out:
# <ipython-input-21-a59c47b41fc5>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]

# %%
shooting.head()
# this has a multi-level index since there are two rows with bolded letters,
# we need to drop one of them so we can index call certain columns for our convinence
# Out:
#   For Real Madrid                                                       \
#              Date   Time     Comp        Round  Day Venue Result GF GA
# 0      2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W  2  0
# 1      2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W  3  1
# 2      2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W  1  0
# 3      2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W  2  1
# 4      2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W  2  1
#
#                   ... Standard               Expected                    \
#         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0  Athletic Club  ...     16.0  2.0  0     0      0.9  0.9    0.07  1.1
# 1        Almería  ...     17.0  1.0  0     0      2.0  2.0    0.08  1.0
# 2     Celta Vigo  ...     19.4  0.0  0     1      1.4  0.6    0.06 -0.4
# 3         Getafe  ...     17.7  0.0  0     0      2.8  2.8    0.11 -0.8
# 4  Real Sociedad  ...     15.9  1.0  0     0      2.0  2.0    0.13  0.0
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0     1.1        Match Report
# 1     1.0        Match Report
# 2     0.4        Match Report
# 3    -0.8        Match Report
# 4     0.0        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result GF GA  \
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W  2  0
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W  3  1
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W  1  0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W  2  1
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W  2  1
#
#         Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  Athletic Club  ...  16.0  2.0   0      0  0.9   0.9     0.07   1.1
# 1        Almería  ...  17.0  1.0   0      0  2.0   2.0     0.08   1.0
# 2     Celta Vigo  ...  19.4  0.0   0      1  1.4   0.6     0.06  -0.4
# 3         Getafe  ...  17.7  0.0   0      0  2.8   2.8     0.11  -0.8
# 4  Real Sociedad  ...  15.9  1.0   0      0  2.0   2.0     0.13   0.0
#
#    np:G-xG  Match Report
# 0      1.1  Match Report
# 1      1.0  Match Report
# 2      0.4  Match Report
# 3     -0.8  Match Report
# 4      0.0  Match Report
#
# [5 rows x 26 columns]

# %% [markdown]
# #Combining Matches and Shooting Data Frames

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result GF GA  \
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W  2  0
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W  3  1
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W  1  0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W  2  1
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W  2  1
#
#         Opponent  ...  Opp Formation              Referee  Match Report  \
# 0  Athletic Club  ...        4-2-3-1            Jesús Gil  Match Report
# 1        Almería  ...        4-2-3-1         José Sánchez  Match Report
# 2     Celta Vigo  ...          5-3-2  Isidro Díaz de Mera  Match Report
# 3         Getafe  ...        4-1-3-2         Mario Melero  Match Report
# 4  Real Sociedad  ...          4-3-3           César Soto  Match Report
#
#    Notes  Sh SoT  Dist   FK PK PKatt
# 0    NaN  14   8  16.0  2.0  0     0
# 1    NaN  25   9  17.0  1.0  0     0
# 2    NaN   9   2  19.4  0.0  0     1
# 3    NaN  26  12  17.7  0.0  0     0
# 4    NaN  17   8  15.9  1.0  0     0
#
# [5 rows x 26 columns]

# %% [markdown]
# #Scrape Data for Multiple Teams for Multiple Years

# %%
years = list(range(2023, 2020, -1))

# %%
years
# Out:
# [2023, 2022, 2021]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/12/2023-2024/2023-2024-La-Liga-Stats"

# %%
import time
for year in years:
  data = requests.get(standings_url)
  soup = BeautifulSoup(data.text)
  standings_table = soup.select('table.stats_table')[0]

  links = [l.get('href') for l in standings_table.find_all('a')]
  links = [l for l in links if '/squads/' in l]
  team_urls = [f"https://fbref.com{l}" for l in links]

  for team_url in team_urls:
    team_name = team_url.split('/')[-1].replace('-Stats', '').replace('-', ' ')
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
    soup = BeautifulSoup(data.text)
    links = [l.get("href") for l in soup.find_all('a')]
    links = [l for l in links if l and 'all_comps/shooting' in l]
    data  = requests.get(f"https://fbref.com{links[0]}")
    shooting = pd.read_html(data.text, match = "Shooting")[0]
    time.sleep(5)
    shooting.columns = shooting.columns.droplevel()
    try:
      team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
    except ValueError:
      continue
    team_data = team_data[team_data['Comp'] == "La Liga"]

    team_data['Season'] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)
    time.sleep(15)
# Out:
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['Season'] = year
# <ipython-input-33-f1c445aa72c7>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data["Team"] = team_name
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['Season'] = year
# <ipython-input-33-f1c445aa72c7>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data["Team"] = team_name
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]
# <ipython-input-33-f1c445aa72c7>:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# <ipython-input-33-f1c445aa72c7>:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match = "Shooting")[0]

# %%
len(all_matches)
# Out:
# 60

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv('matches.csv')

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W   2   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0  Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0
# 1        Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2     Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3         Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4  Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
#
#   season         team
# 0   2023  Real Madrid
# 1   2023  Real Madrid
# 2   2023  Real Madrid
# 3   2023  Real Madrid
# 4   2023  Real Madrid
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (2280, 28)

# %%
matches['team'].value_counts()
# Out:
# team
# Real Madrid        114
# Barcelona          114
# Almeria            114
# Cadiz              114
# Rayo Vallecano     114
# Las Palmas         114
# Mallorca           114
# Sevilla            114
# Celta Vigo         114
# Getafe             114
# Osasuna            114
# Alaves             114
# Valencia           114
# Villarreal         114
# Real Betis         114
# Real Sociedad      114
# Athletic Club      114
# Atletico Madrid    114
# Girona             114
# Granada            114
# Name: count, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# round
# Matchweek 1     60
# Matchweek 29    60
# Matchweek 20    60
# Matchweek 23    60
# Matchweek 24    60
# Matchweek 25    60
# Matchweek 26    60
# Matchweek 27    60
# Matchweek 28    60
# Matchweek 30    60
# Matchweek 2     60
# Matchweek 31    60
# Matchweek 32    60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 35    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 22    60
# Matchweek 21    60
# Matchweek 19    60
# Matchweek 18    60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 7     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 12    60
# Matchweek 13    60
# Matchweek 14    60
# Matchweek 15    60
# Matchweek 16    60
# Matchweek 17    60
# Matchweek 38    60
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date']) #conveting exsiting column into a date type so its type is no longer an object

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %% [markdown]
# #Creating pedictors for machine learning

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes #taking into account the venue for home field advantage

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes #creating codes for each specific opponent

# %%
matches['hour'] = matches['time'].str.replace(":.+", "", regex=True).astype('int') #creating the hour column into integers to let the machine learning use this

# %%
matches['day_code'] = matches['date'].dt.dayofweek #creating day of the week column

# %% [markdown]
# ##Training Machine Learning Model

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
train = matches[matches['date'] < '2024-01-01'] #train variable is set to be any matches before 2023 so it can have all the data before so we can predict matches in the future

# %%
test = matches[matches['date'] > '2024-01-01'] #test matches are matches in the future so it can predict matches after our sample space from our web scraping data

# %%
predictors = ['venue_code', "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train['target']) #.fit method will train a rf model with the predictors trying to predict the target
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.6225

# %%
combined = pd.DataFrame(dict(actual = test['target'], prediction = preds))

# %%
pd.crosstab(index = combined['actual'], columns = combined['prediction'])
# Out:
# prediction    0    1
# actual
# 0           585  165
# 1           288  162

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], preds)
# Out:
# 0.4954128440366973

# %% [markdown]
# #Now we improve precision with rolling averages (this will increase the precision on future matches based on our data)

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Real Madrid').sort_values('date')

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values('date')
  rolling_stats = group[cols].rolling(3, closed = 'left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset = new_cols)
  return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 52 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Away      D   4   4
# 52 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Away      D   4   4
# 53 2024-05-25  21:00  La Liga  Matchweek 38  Sat  Home      D   0   0
# 53 2024-05-25  21:00  La Liga  Matchweek 38  Sat  Home      D   0   0
# 53 2024-05-25  21:00  La Liga  Matchweek 38  Sat  Home      D   0   0
#
#       opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 1      Almería  ...         5       1    2.000000    0.000000  14.000000
# 1      Almería  ...         5       1    2.333333    0.333333  17.666667
# 1      Almería  ...         5       1    2.666667    0.666667  21.333333
# 2   Celta Vigo  ...         4       1    3.000000    1.000000  25.000000
# 2   Celta Vigo  ...         4       1    2.333333    0.666667  19.666667
# ..         ...  ...       ...     ...         ...         ...        ...
# 52  Villarreal  ...         6       0    4.666667    1.333333  18.666667
# 52  Villarreal  ...         6       0    4.333333    2.666667  15.333333
# 53       Betis  ...         5       0    4.000000    4.000000  12.000000
# 53       Betis  ...         5       0    2.666667    2.666667  12.333333
# 53       Betis  ...         5       0    1.333333    1.333333  12.666667
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 1     8.000000    16.000000   2.000000        0.0       0.000000
# 1     8.333333    16.333333   1.666667        0.0       0.000000
# 1     8.666667    16.666667   1.333333        0.0       0.000000
# 2     9.000000    17.000000   1.000000        0.0       0.000000
# 2     6.666667    17.800000   0.666667        0.0       0.333333
# ..         ...          ...        ...        ...            ...
# 52    9.333333    16.633333   0.666667        0.0       0.000000
# 52    7.666667    17.266667   0.333333        0.0       0.000000
# 53    6.000000    17.900000   0.000000        0.0       0.000000
# 53    5.333333    18.200000   0.333333        0.0       0.000000
# 53    4.666667    18.500000   0.666667        0.0       0.000000
#
# [111 rows x 41 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-101-f49e376da466>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     date   time     comp         round  day venue result  gf  \
# team
# Alaves     1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4
#            1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4
#            1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4
#            2  2023-08-28  19:30  La Liga   Matchweek 3  Mon  Away      L   0
#            2  2023-08-28  19:30  La Liga   Matchweek 3  Mon  Away      L   0
# ...                  ...    ...      ...           ...  ...   ...    ...  ..
# Villarreal 47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4
#            47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1
#
#                ga     opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# team                            ...
# Alaves     1    3      Sevilla  ...         0       1    0.000000    1.000000
#            1    3      Sevilla  ...         0       1    1.333333    1.666667
#            1    3      Sevilla  ...         0       1    2.666667    2.333333
#            2    1       Getafe  ...         0       0    4.000000    3.000000
#            2    1       Getafe  ...         0       0    2.666667    2.333333
# ...            ..          ...  ...       ...     ...         ...         ...
# Villarreal 47   4  Real Madrid  ...         6       0    2.000000    1.333333
#            47   4  Real Madrid  ...         6       0    3.000000    2.666667
#            48   1      Osasuna  ...         5       0    4.000000    4.000000
#            48   1      Osasuna  ...         5       0    3.000000    3.000000
#            48   1      Osasuna  ...         5       0    2.000000    2.000000
#
#               sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  \
# team
# Alaves     1   10.000000    2.000000    22.100000   0.000000        0.0
#            1   11.333333    3.666667    20.100000   0.333333        0.0
#            1   12.666667    5.333333    18.100000   0.666667        0.0
#            2   14.000000    7.000000    16.100000   1.000000        0.0
#            2   14.666667    5.000000    17.033333   0.666667        0.0
# ...                  ...         ...          ...        ...        ...
# Villarreal 47  14.333333    4.333333    18.000000   0.000000        0.0
#            47  17.666667    5.666667    16.800000   0.000000        0.0
#            48  21.000000    7.000000    15.600000   0.000000        0.0
#            48  17.666667    5.666667    16.166667   0.000000        0.0
#            48  14.333333    4.333333    16.733333   0.000000        0.0
#
#                pkatt_rolling
# team
# Alaves     1             0.0
#            1             0.0
#            1             0.0
#            2             0.0
#            2             0.0
# ...                      ...
# Villarreal 47            0.0
#            47            0.0
#            48            0.0
#            48            0.0
#            48            0.0
#
# [2220 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4   3
# 1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4   3
# 1  2023-08-21  19:00  La Liga   Matchweek 2  Mon  Home      W   4   3
# 2  2023-08-28  19:30  La Liga   Matchweek 3  Mon  Away      L   0   1
# 2  2023-08-28  19:30  La Liga   Matchweek 3  Mon  Away      L   0   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4   4
# 47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4   4
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1   1
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1   1
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1   1
#
#        opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 1       Sevilla  ...         0       1    0.000000    1.000000  10.000000
# 1       Sevilla  ...         0       1    1.333333    1.666667  11.333333
# 1       Sevilla  ...         0       1    2.666667    2.333333  12.666667
# 2        Getafe  ...         0       0    4.000000    3.000000  14.000000
# 2        Getafe  ...         0       0    2.666667    2.333333  14.666667
# ..          ...  ...       ...     ...         ...         ...        ...
# 47  Real Madrid  ...         6       0    2.000000    1.333333  14.333333
# 47  Real Madrid  ...         6       0    3.000000    2.666667  17.666667
# 48      Osasuna  ...         5       0    4.000000    4.000000  21.000000
# 48      Osasuna  ...         5       0    3.000000    3.000000  17.666667
# 48      Osasuna  ...         5       0    2.000000    2.000000  14.333333
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 1     2.000000    22.100000   0.000000        0.0            0.0
# 1     3.666667    20.100000   0.333333        0.0            0.0
# 1     5.333333    18.100000   0.666667        0.0            0.0
# 2     7.000000    16.100000   1.000000        0.0            0.0
# 2     5.000000    17.033333   0.666667        0.0            0.0
# ..         ...          ...        ...        ...            ...
# 47    4.333333    18.000000   0.000000        0.0            0.0
# 47    5.666667    16.800000   0.000000        0.0            0.0
# 48    7.000000    15.600000   0.000000        0.0            0.0
# 48    5.666667    16.166667   0.000000        0.0            0.0
# 48    4.333333    16.733333   0.000000        0.0            0.0
#
# [2220 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
  train = data[data['date'] < '2024-01-01']
  test = data[data['date'] > '2024-01-01']
  rf.fit(train[predictors], train['target'])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test['target'], predicted=preds), index=test.index)
  error = precision_score(test['target'], preds)
  return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.6363636363636364

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date    team       opponent result
# 51       0          0 2024-01-02  Alaves  Real Sociedad      D
# 52       0          0 2024-01-02  Alaves  Real Sociedad      D
# 53       0          0 2024-01-02  Alaves  Real Sociedad      D
# 54       1          0 2024-01-12  Alaves        Sevilla      W
# 55       1          0 2024-01-12  Alaves        Sevilla      W
# 56       1          0 2024-01-12  Alaves        Sevilla      W
# 57       1          1 2024-01-19  Alaves          Cádiz      W
# 58       1          1 2024-01-19  Alaves          Cádiz      W
# 59       1          1 2024-01-19  Alaves          Cádiz      W
# 60       1          0 2024-01-26  Alaves        Almería      W

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    'Real Madrid CF': 'Real Madrid',
    'FC Barcelond': 'Barcelona',
    'Sevilla FC': 'Sevilla',
    'Real Sociedad': 'Sociedad',
    'Valencia CF': 'Valencia',
    'Villarreal CF': 'Villarreal',
    'Real Betis': 'Betis',
    'Athletic Club': 'Athletic Bilbao',
    'RCD Mallorca': 'Mallorca',
    'Celta de Vigo': 'Celta Vigo',
    'Getafe CF': 'Getafe',
    'UD Almeria': 'Almeria',
    'Granada CF': 'Granada',
    'Deportivo Alaves': 'Alaves',
    'CA Osasuna': 'Osasuna',
    'Rayo Vallecano': 'Rayo',
    'Girona FC': 'Girona',
    'UD Las Palmas': 'Las Palmas',
    'Cadiz CF': 'Cadiz',
    'Elche CF': 'Elche',
    'Levante UD': 'Levante',
    'SD Eibar': 'Eibar',
    'Espanyol': 'Espanyol',
    'Huesca': 'Huesca',
    'Real Valladolid': 'Valladolid'
}
mapping = MissingDict(**map_values)

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date        team       opponent result  \
# 51         0          0 2024-01-02      Alaves  Real Sociedad      D
# 52         0          0 2024-01-02      Alaves  Real Sociedad      D
# 53         0          0 2024-01-02      Alaves  Real Sociedad      D
# 54         1          0 2024-01-12      Alaves        Sevilla      W
# 55         1          0 2024-01-12      Alaves        Sevilla      W
# ...      ...        ...        ...         ...            ...    ...
# 2215       0          1 2024-05-19  Villarreal    Real Madrid      D
# 2216       0          0 2024-05-19  Villarreal    Real Madrid      D
# 2217       0          1 2024-05-25  Villarreal        Osasuna      D
# 2218       0          0 2024-05-25  Villarreal        Osasuna      D
# 2219       0          0 2024-05-25  Villarreal        Osasuna      D
#
#         new_team
# 51        Alaves
# 52        Alaves
# 53        Alaves
# 54        Alaves
# 55        Alaves
# ...          ...
# 2215  Villarreal
# 2216  Villarreal
# 2217  Villarreal
# 2218  Villarreal
# 2219  Villarreal
#
# [1200 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=['date', 'new_team'], right_on = ['date', 'opponent'])

# %%
merged
# Out:
#       actual_x  predicted_x       date      team_x  opponent_x result_x  \
# 0            1            0 2024-01-04   Barcelona  Las Palmas        W
# 1            1            0 2024-01-04   Barcelona  Las Palmas        W
# 2            1            0 2024-01-04   Barcelona  Las Palmas        W
# 3            1            1 2024-01-04   Barcelona  Las Palmas        W
# 4            1            1 2024-01-04   Barcelona  Las Palmas        W
# ...        ...          ...        ...         ...         ...      ...
# 2335         0            0 2024-05-25  Villarreal     Osasuna        D
# 2336         0            0 2024-05-25  Villarreal     Osasuna        D
# 2337         0            0 2024-05-25  Villarreal     Osasuna        D
# 2338         0            0 2024-05-25  Villarreal     Osasuna        D
# 2339         0            0 2024-05-25  Villarreal     Osasuna        D
#
#       new_team_x  actual_y  predicted_y      team_y  opponent_y result_y  \
# 0      Barcelona         0            0  Las Palmas   Barcelona        L
# 1      Barcelona         0            0  Las Palmas   Barcelona        L
# 2      Barcelona         0            0  Las Palmas   Barcelona        L
# 3      Barcelona         0            0  Las Palmas   Barcelona        L
# 4      Barcelona         0            0  Las Palmas   Barcelona        L
# ...          ...       ...          ...         ...         ...      ...
# 2335  Villarreal         0            1     Osasuna  Villarreal        D
# 2336  Villarreal         0            1     Osasuna  Villarreal        D
# 2337  Villarreal         0            1     Osasuna  Villarreal        D
# 2338  Villarreal         0            1     Osasuna  Villarreal        D
# 2339  Villarreal         0            1     Osasuna  Villarreal        D
#
#       new_team_y
# 0     Las Palmas
# 1     Las Palmas
# 2     Las Palmas
# 3     Las Palmas
# 4     Las Palmas
# ...          ...
# 2335     Osasuna
# 2336     Osasuna
# 2337     Osasuna
# 2338     Osasuna
# 2339     Osasuna
#
# [2340 rows x 13 columns]

# %%
merged[(merged['predicted_x'] == 1) & (merged['predicted_y'] == 0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    347
# 0    154
# Name: count, dtype: int64

# %%
347/511 # this is the improved accuracy for our machine learning model
# Out:
# 0.6790606653620352
